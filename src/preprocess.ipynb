# %%
import pandas as pd
data = pd.read_csv('./data/highway.csv',sep='\t',header=None)
data.columns = ["text"]
data.head()
# Out:
#                text
# 0             测试情报板
# 1  测试测试情报板，广惠高速欢迎您您
# 2  测试测试情报板，广惠高速欢迎您您
# 3  测试测试情报板，广惠高速欢迎您您
# 4     测试情报板，广惠高速欢迎您

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1648181 entries, 0 to 1648180
# Data columns (total 1 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   text    1648181 non-null  object
# dtypes: object(1)
# memory usage: 12.6+ MB

# %%
all = data.drop_duplicates(subset=None, keep='last')

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22574 entries, 3 to 1648180
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    22574 non-null  object
# dtypes: object(1)
# memory usage: 352.7+ KB

# %%
all.to_csv("./data/all-20220510.txt",index=False)

# %%
#最好检查下段文本的最大长度，代码中默认都是max_length=100
